# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn_pandas import DataFrameMapper

# %%
df =pd.read_csv('..\data\steam_cleaned.csv', index_col= 'Unique_ID')

# %%
df = df.drop('year', axis = 1)

# %%
mapper = DataFrameMapper([(df.columns, StandardScaler())])
scaled_features = mapper.fit_transform(df.copy())
scaled_features_df = pd.DataFrame(scaled_features, index=df.index, columns=df.columns)

# %%
df_transpose = scaled_features_df.transpose()
correlation_df = df_transpose.corr()

# %%
correlation_df
# Out:
# Unique_ID   1643320   2172860   1364780   1868180   1868170   1810820  \
# Unique_ID
# 1643320    1.000000  0.136167  0.043773  0.056643  0.055719  0.055719
# 2172860    0.136167  1.000000  0.056007  0.178943  0.060229  0.060229
# 1364780    0.043773  0.056007  1.000000  0.039528  0.038834  0.038834
# 1868180    0.056643  0.178943  0.039528  1.000000  0.883709  0.883709
# 1868170    0.055719  0.060229  0.038834  0.883709  1.000000  1.000000
# ...             ...       ...       ...       ...       ...       ...
# 335610     0.142315  0.159939  0.114241  0.103098  0.102472  0.102472
# 249860    -0.035702 -0.026903 -0.012521 -0.030370 -0.029527 -0.029527
# 49540      0.137338 -0.007405  0.004536 -0.014140 -0.013850 -0.013850
# 418770    -0.014359  0.190283  0.101216  0.074258  0.073959  0.073959
# 57925      0.128078 -0.014475 -0.041985 -0.087433 -0.085109 -0.085109
#
# Unique_ID   1485590   1294810   1774580   1798020  ...   592370    418800   \
# Unique_ID                                          ...
# 1643320    0.016024  0.400800  0.059690  0.010102  ...  0.000100 -0.002309
# 2172860    0.018858  0.188877  0.068867  0.028580  ...  0.023369  0.145228
# 1364780    0.139160  0.105110  0.077233  0.127338  ...  0.403012  0.083007
# 1868180    0.227534  0.067083  0.049637  0.015275  ...  0.007869  0.056200
# 1868170    0.223489  0.066045  0.048809  0.015113  ...  0.008089  0.055886
# ...             ...       ...       ...       ...  ...       ...       ...
# 335610     0.084209  0.166087  0.132284  0.041372  ...  0.109979  0.295848
# 249860     0.010333 -0.027215 -0.017714 -0.012360  ... -0.006045 -0.035997
# 49540     -0.002764  0.278549  0.100522 -0.012327  ...  0.000683 -0.011049
# 418770     0.065838  0.121726  0.097951  0.088622  ...  0.168443  0.723464
# 57925     -0.029133  0.195425 -0.060128 -0.021603  ...  0.121989  0.063986
#
# Unique_ID   418790    564310    237810    335610    249860    49540    \
# Unique_ID
# 1643320    0.011976  0.045481  0.021118  0.142315 -0.035702  0.137338
# 2172860    0.208572 -0.045459  0.069789  0.159939 -0.026903 -0.007405
# 1364780    0.123032 -0.047921  0.012083  0.114241 -0.012521  0.004536
# 1868180    0.088595 -0.083213  0.047258  0.103098 -0.030370 -0.014140
# 1868170    0.088038 -0.081528  0.046631  0.102472 -0.029527 -0.013850
# ...             ...       ...       ...       ...       ...       ...
# 335610     0.428027 -0.095057  0.122462  1.000000  0.001253 -0.000458
# 249860    -0.038350 -0.035159 -0.015616  0.001253  1.000000 -0.008201
# 49540     -0.002613  0.227906 -0.032805 -0.000458 -0.008201  1.000000
# 418770     0.993926  0.075261  0.260796  0.390961 -0.035889 -0.009218
# 57925      0.114538  0.355295 -0.049061  0.008129 -0.011576  0.163015
#
# Unique_ID   418770    57925
# Unique_ID
# 1643320   -0.014359  0.128078
# 2172860    0.190283 -0.014475
# 1364780    0.101216 -0.041985
# 1868180    0.074258 -0.087433
# 1868170    0.073959 -0.085109
# ...             ...       ...
# 335610     0.390961  0.008129
# 249860    -0.035889 -0.011576
# 49540     -0.009218  0.163015
# 418770     1.000000  0.126380
# 57925      0.126380  1.000000
#
# [9286 rows x 9286 columns]

# %%
test = correlation_df[1643320].values

# %%
np.sort(test)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 np.sort(test, axis = 1)
#
# File <__array_function__ internals>:200, in sort(*args, **kwargs)
#
# File c:\Users\paulj\SteamRecommender\.venv\Lib\site-packages\numpy\core\fromnumeric.py:1030, in sort(a, axis, kind, order)
#    1028 else:
#    1029     a = asanyarray(a).copy(order="K")
# -> 1030 a.sort(axis=axis, kind=kind, order=order)
#    1031 return a
#
# AxisError: axis 1 is out of bounds for array of dimension 1
